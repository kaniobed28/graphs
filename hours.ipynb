# %%
import pandas as pd
import numpy as np

# %%
headers = ['HH:mm:ss',   'foF2',   'h`F',   'hmF2']
# navalues =[9999,99999,999.9, 999999.99,99999.9,999999.99, 
#            99.99,99999.99,999.99,99999.99, 99.99000,999999.99,999999.99,99999.99]

data = pd.read_csv('NEW 29.txt',sep ='\s+', skiprows=13, names =headers)

# index =  pd.to_datetime(data["HH:mm:ss"])

# data.set_index(index, inplace =True)

# %%
data.head(9)
# Out:
#   HH:mm:ss  foF2    h`F   hmF2
# 0    02:30  11.5  273.3  327.2
# 1    02:45  11.4  245.6  317.4
# 2    03:00    11  249.6  344.4
# 3    03:15  10.2  253.5  322.2
# 4    03:30   9.5  252.5  327.5
# 5    03:45   9.3  269.3    342
# 6    04:00   9.3  273.3  356.2
# 7    04:15     9    293  361.9
# 8    04:30   9.1  304.9    367

# %%
import matplotlib
import matplotlib.pyplot as plt
import datetime
import fnmatch
from matplotlib import dates
import matplotlib
from matplotlib import dates
from matplotlib.ticker import (MultipleLocator, AutoMinorLocator)

# %%
data["HH:mm:ss"][85:]
# Out:
# 85    23:45
# Name: HH:mm:ss, dtype: object

# %%
data[["HH:mm:ss"]].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86 entries, 0 to 85
# Data columns (total 1 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   HH:mm:ss  86 non-null     object
# dtypes: object(1)
# memory usage: 816.0+ bytes

# %%
fig, axs = plt.subplots(3, 1, figsize=(15, 20), facecolor='w', edgecolor='k')




# axs[0].set_ylim([0,4700])

axs[0].plot(data.index,data["h`F"],lw=2)
# axs[1].plot(data["HH:mm:ss"],data['hmF2'])
# axs[2].plot(data["HH:mm:ss"],data['foF2'])

# x = ['00','03','06','09','12','15','18','21']

# x = ["8","16","20"]

# x = pd.DataFrame(x,columns=["x"])

#axs[0].set_yticklabels(np.arange(0,470,50),fontsize= 28)

axs[0].set_xticklabels(x["x"],fontsize= 28)
# axs[1].set_xticklabels(x["x"],fontsize= 28)
# axs[2].set_xticklabels(x["x"],fontsize= 28)

# axs[0].tick_params(labelbottom = False)
# axs[1].tick_params(labelbottom = False)

axs[0].set_xticklabels(np.arange(0,20,4),fontsize= 28)
fig.text(0.5, 0.04, 'Hours', ha='center',size = 32 ,weight = 'bold')# This line of code is for labeling the x-axis 'Month'.
fig.align_ylabels()

plt.show()
# Out:
# C:\Users\kanio\AppData\Local\Temp/ipykernel_7252/3505286143.py:20: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[0].set_xticklabels(x["x"],fontsize= 28)
# C:\Users\kanio\AppData\Local\Temp/ipykernel_7252/3505286143.py:27: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[0].set_xticklabels(np.arange(0,20,4),fontsize= 28)

# %%
data["h`F"].min()
# Out:
# '---'

# %%
data["h`F"].max()
# Out:
# '545.8'

# %%
len(data["HH:mm:ss"].unique())
# Out:
# 86

# %%
data["HH:mm:ss"].unique()
# Out:
# array(['02:30', '02:45', '03:00', '03:15', '03:30', '03:45', '04:00',
#        '04:15', '04:30', '04:45', '05:00', '05:15', '05:30', '05:45',
#        '06:00', '06:15', '06:30', '06:45', '07:00', '07:15', '07:30',
#        '07:45', '08:00', '08:15', '08:30', '08:45', '09:00', '09:15',
#        '09:30', '09:45', '10:00', '10:15', '10:30', '10:45', '11:00',
#        '11:15', '11:30', '11:45', '12:00', '12:15', '12:30', '12:45',
#        '13:00', '13:15', '13:30', '13:45', '14:00', '14:15', '14:30',
#        '14:45', '15:00', '15:15', '15:30', '15:45', '16:00', '16:15',
#        '16:30', '16:45', '17:00', '17:15', '17:30', '17:45', '18:00',
#        '18:15', '18:30', '18:45', '19:00', '19:15', '19:30', '19:45',
#        '20:00', '20:15', '20:30', '20:45', '21:00', '21:15', '21:30',
#        '21:45', '22:00', '22:15', '22:30', '22:45', '23:00', '23:15',
#        '23:30', '23:45'], dtype=object)

# %%
data.index
# Out:
# RangeIndex(start=0, stop=86, step=1)

# %%
plt.plot(data.index,data["h`F"])

# %%
data.index
# Out:
# RangeIndex(start=0, stop=86, step=1)
